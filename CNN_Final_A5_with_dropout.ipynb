# %% [markdown]
# <a href="https://colab.research.google.com/github/zahra370/DL_assignments/blob/main/CNN_Final_A5_with_dropout.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf

# Display the version
print(tf.__version__)	

# other imports
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Input, Conv2D, Dense, Flatten, Dropout
from tensorflow.keras.layers import GlobalMaxPooling2D, MaxPooling2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.models import Model
# Out:
# 2.9.2

# %%
# Load in the data
cifar10 = tf.keras.datasets.cifar10

# Distribute it to train and test set
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print(x_train.shape, y_train.shape, x_test.shape, y_test.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 4s 0us/step
# (50000, 32, 32, 3) (50000, 1) (10000, 32, 32, 3) (10000, 1)

# %%
X_train = x_train[:40000]
X_val = x_train[40000:]

Y_train = y_train[:40000]
Y_val = y_train[40000:]

X_test = x_test
Y_test = y_test

# shape of the train validation and test dataset

print('shape of train images',X_train.shape)
print('shape of train label',Y_train.shape)

print('shape of validation images',X_val.shape)
print('shape of validation label',Y_val.shape)

print('shape of test images',X_test.shape)
print('shape of test label',Y_test.shape)
# Out:
# shape of train images (40000, 32, 32, 3)
# shape of train label (40000, 1)
# shape of validation images (10000, 32, 32, 3)
# shape of validation label (10000, 1)
# shape of test images (10000, 32, 32, 3)
# shape of test label (10000, 1)

# %%
#  Data Preprocessing steps

# Reduce pixel values
X_train, X_val, X_test = X_train / 255.0,X_val / 255.0, X_test / 255.0
 
# flatten the label values
Y_train, Y_val, Y_test = Y_train.flatten(),Y_val.flatten(), Y_test.flatten()

# %%
# visualize data by plotting images
fig, ax = plt.subplots(5, 5)
k = 0
 
for i in range(5):
    for j in range(5):
        ax[i][j].imshow(x_train[k], aspect='auto')
        k += 1
 
plt.show()

# %% [markdown]
# ELU is selected based on the heighest Accuracy and lowest loss, table is given in the report.

# %%
from keras.layers import LeakyReLU
from keras.initializers import Constant
from keras.layers import PReLU
from keras.layers import ELU


# number of classes
K = len(set(Y_train))
 
# calculate total number of classes
# for output layer
print("number of classes:", K)
 
# Build the model using the functional API
# input layer

# Build the model using the functional API
# input layer
i = Input(shape=x_train[0].shape)

x = Conv2D(32, (3, 3), activation='elu', padding='same')(i)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)
x = Dropout(0.2)(x)

x = Conv2D(64, (3, 3), activation='elu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)
x = Dropout(0.2)(x)
 
x = Conv2D(128, (3, 3), activation='elu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)
x = Dropout(0.2)(x)
 
x = Flatten()(x)
x = Dropout(0.2)(x)
 
# Hidden layer
x = Dense(1024, activation='elu')(x)
x = Dropout(0.2)(x)

# Second Hidden layer
x = Dense(256, activation='elu')(x)
x = Dropout(0.2)(x)
 

# last hidden layer i.e.. output layer
x = Dense(K, activation='softmax')(x)
 
model = Model(i, x)
 
# model description
model.summary()
# Out:
# number of classes: 10
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv2d_9 (Conv2D)           (None, 32, 32, 32)        896
#
#  batch_normalization_9 (Batc  (None, 32, 32, 32)       128
#  hNormalization)
#
#  max_pooling2d_6 (MaxPooling  (None, 16, 16, 32)       0
#  2D)
#
#  dropout_6 (Dropout)         (None, 16, 16, 32)        0
#
#  conv2d_10 (Conv2D)          (None, 16, 16, 64)        18496
#
#  batch_normalization_10 (Bat  (None, 16, 16, 64)       256
#  chNormalization)
#
#  max_pooling2d_7 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  dropout_7 (Dropout)         (None, 8, 8, 64)          0
#
#  conv2d_11 (Conv2D)          (None, 8, 8, 128)         73856
#
#  batch_normalization_11 (Bat  (None, 8, 8, 128)        512
#  chNormalization)
#
#  max_pooling2d_8 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  dropout_8 (Dropout)         (None, 4, 4, 128)         0
#
#  flatten_2 (Flatten)         (None, 2048)              0
#
#  dropout_9 (Dropout)         (None, 2048)              0
#
#  dense_6 (Dense)             (None, 1024)              2098176
#
#  dropout_10 (Dropout)        (None, 1024)              0
#
#  dense_7 (Dense)             (None, 256)               262400
#
#  dropout_11 (Dropout)        (None, 256)               0
#
#  dense_8 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 2,457,290
# Trainable params: 2,456,842
# Non-trainable params: 448
# _________________________________________________________________

# %% [markdown]
# Default value of Learning rate = 0.001 is used

# %%
# Compile
model.compile(optimizer='adam',
			loss='sparse_categorical_crossentropy',
			metrics=['accuracy'])

# Fit
r = model.fit(
X_train, Y_train ,validation_data=(X_val, Y_val), epochs=50)
# Out:
# Epoch 1/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 1.7064 - accuracy: 0.4103 - val_loss: 1.1674 - val_accuracy: 0.5785
# Epoch 2/50
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.2246 - accuracy: 0.5701 - val_loss: 1.0075 - val_accuracy: 0.6423
# Epoch 3/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 1.0238 - accuracy: 0.6454 - val_loss: 1.0160 - val_accuracy: 0.6390
# Epoch 4/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.9143 - accuracy: 0.6825 - val_loss: 0.9850 - val_accuracy: 0.6607
# Epoch 5/50
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.8352 - accuracy: 0.7089 - val_loss: 0.8427 - val_accuracy: 0.7138
# Epoch 6/50
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.7658 - accuracy: 0.7351 - val_loss: 1.0467 - val_accuracy: 0.6371
# Epoch 7/50
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6990 - accuracy: 0.7581 - val_loss: 0.7868 - val_accuracy: 0.7380
# Epoch 8/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.6639 - accuracy: 0.7740 - val_loss: 0.6880 - val_accuracy: 0.7740
# Epoch 9/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.6094 - accuracy: 0.7896 - val_loss: 0.7353 - val_accuracy: 0.7653
# Epoch 10/50
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.5748 - accuracy: 0.8036 - val_loss: 0.9652 - val_accuracy: 0.7167
# Epoch 11/50
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.5412 - accuracy: 0.8151 - val_loss: 0.9242 - val_accuracy: 0.7154
# Epoch 12/50
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.5062 - accuracy: 0.8255 - val_loss: 0.7343 - val_accuracy: 0.7609
# Epoch 13/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.4803 - accuracy: 0.8340 - val_loss: 0.7132 - val_accuracy: 0.7706
# Epoch 14/50
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.4660 - accuracy: 0.8393 - val_loss: 0.7951 - val_accuracy: 0.7601
# Epoch 15/50
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.4371 - accuracy: 0.8515 - val_loss: 0.7010 - val_accuracy: 0.7832
# Epoch 16/50
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.4135 - accuracy: 0.8575 - val_loss: 0.8193 - val_accuracy: 0.7699
# Epoch 17/50
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.3972 - accuracy: 0.8645 - val_loss: 0.7426 - val_accuracy: 0.7755
# Epoch 18/50
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.3896 - accuracy: 0.8692 - val_loss: 0.8313 - val_accuracy: 0.7707
# Epoch 19/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.3703 - accuracy: 0.8752 - val_loss: 0.8720 - val_accuracy: 0.7508
# Epoch 20/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.3556 - accuracy: 0.8803 - val_loss: 0.8872 - val_accuracy: 0.7538
# Epoch 21/50
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.3372 - accuracy: 0.8891 - val_loss: 0.7834 - val_accuracy: 0.7866
# Epoch 22/50
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.3304 - accuracy: 0.8892 - val_loss: 0.9568 - val_accuracy: 0.7658
# Epoch 23/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.3265 - accuracy: 0.8911 - val_loss: 0.7029 - val_accuracy: 0.7980
# Epoch 24/50
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.3112 - accuracy: 0.8980 - val_loss: 0.8677 - val_accuracy: 0.7626
# Epoch 25/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.3054 - accuracy: 0.8977 - val_loss: 0.8253 - val_accuracy: 0.7798
# Epoch 26/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.2965 - accuracy: 0.9008 - val_loss: 0.7214 - val_accuracy: 0.8010
# Epoch 27/50
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.2810 - accuracy: 0.9087 - val_loss: 0.7482 - val_accuracy: 0.7874
# Epoch 28/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.2827 - accuracy: 0.9074 - val_loss: 0.7539 - val_accuracy: 0.7894
# Epoch 29/50
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.2661 - accuracy: 0.9123 - val_loss: 0.8228 - val_accuracy: 0.7948
# Epoch 30/50
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.2743 - accuracy: 0.9112 - val_loss: 0.7269 - val_accuracy: 0.8085
# Epoch 31/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.2595 - accuracy: 0.9143 - val_loss: 0.7885 - val_accuracy: 0.7940
# Epoch 32/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.2575 - accuracy: 0.9153 - val_loss: 0.9552 - val_accuracy: 0.7659
# Epoch 33/50
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.2462 - accuracy: 0.9202 - val_loss: 0.8311 - val_accuracy: 0.7998
# Epoch 34/50
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.2411 - accuracy: 0.9201 - val_loss: 0.8977 - val_accuracy: 0.7773
# Epoch 35/50
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.2470 - accuracy: 0.9215 - val_loss: 0.7960 - val_accuracy: 0.7887
# Epoch 36/50
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.2354 - accuracy: 0.9238 - val_loss: 0.8038 - val_accuracy: 0.7987
# Epoch 37/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.2321 - accuracy: 0.9257 - val_loss: 0.8167 - val_accuracy: 0.7987
# Epoch 38/50
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.2263 - accuracy: 0.9274 - val_loss: 0.8887 - val_accuracy: 0.8028
# Epoch 39/50
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.2233 - accuracy: 0.9283 - val_loss: 0.8090 - val_accuracy: 0.7930
# Epoch 40/50
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.2263 - accuracy: 0.9282 - val_loss: 0.8843 - val_accuracy: 0.7941
# Epoch 41/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.2151 - accuracy: 0.9330 - val_loss: 0.8130 - val_accuracy: 0.7985
# Epoch 42/50
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.2077 - accuracy: 0.9334 - val_loss: 0.7961 - val_accuracy: 0.7987
# Epoch 43/50
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.2013 - accuracy: 0.9356 - val_loss: 0.9034 - val_accuracy: 0.7936
# Epoch 44/50
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.2096 - accuracy: 0.9342 - val_loss: 0.8921 - val_accuracy: 0.8016
# Epoch 45/50
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.2082 - accuracy: 0.9358 - val_loss: 0.9692 - val_accuracy: 0.7846
# Epoch 46/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.2093 - accuracy: 0.9330 - val_loss: 1.0368 - val_accuracy: 0.7648
# Epoch 47/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.1976 - accuracy: 0.9389 - val_loss: 0.9458 - val_accuracy: 0.7973
# Epoch 48/50
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.1867 - accuracy: 0.9421 - val_loss: 0.9118 - val_accuracy: 0.7919
# Epoch 49/50
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.1949 - accuracy: 0.9388 - val_loss: 1.0906 - val_accuracy: 0.7573
# Epoch 50/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.1888 - accuracy: 0.9417 - val_loss: 0.9558 - val_accuracy: 0.7869

# %%
# Plot accuracy per iteration
plt.plot(r.history['accuracy'], label='acc')
plt.plot(r.history['val_accuracy'], label='val_acc')
plt.legend()

# %%
plt.plot(r.history['loss'], label='Training loss')
plt.plot(r.history['val_loss'], label='Validation loss')
plt.title('ELU training / validation loss values')
plt.ylabel('Loss value')
plt.xlabel('Epoch')
plt.legend(loc="upper left")
plt.show()

# %%
# Fit with data augmentation
# Note: if you run this AFTER calling
# the previous model.fit()
# it will CONTINUE training where it left off
batch_size = 32
data_generator = tf.keras.preprocessing.image.ImageDataGenerator(
width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)

train_generator = data_generator.flow(X_train, Y_train, batch_size)
# steps_per_epoch = x_train.shape[0] / batch_size

r = model.fit(train_generator, validation_data=(X_test, Y_test),
			steps_per_epoch= 500, epochs=50)
# Out:
# Epoch 1/50
# 500/500 [==============================] - 12s 22ms/step - loss: 0.7555 - accuracy: 0.7779 - val_loss: 0.6396 - val_accuracy: 0.8030
# Epoch 2/50
# 500/500 [==============================] - 11s 22ms/step - loss: 0.6089 - accuracy: 0.8093 - val_loss: 0.6086 - val_accuracy: 0.8125
# Epoch 3/50
# 500/500 [==============================] - 11s 21ms/step - loss: 0.5590 - accuracy: 0.8272 - val_loss: 0.6164 - val_accuracy: 0.8155
# Epoch 4/50
# 500/500 [==============================] - 11s 21ms/step - loss: 0.5394 - accuracy: 0.8320 - val_loss: 0.5745 - val_accuracy: 0.8226
# Epoch 5/50
# 500/500 [==============================] - 11s 22ms/step - loss: 0.5313 - accuracy: 0.8354 - val_loss: 0.6676 - val_accuracy: 0.8035
# Epoch 6/50
# 500/500 [==============================] - 11s 22ms/step - loss: 0.5096 - accuracy: 0.8407 - val_loss: 0.5601 - val_accuracy: 0.8267
# Epoch 7/50
# 500/500 [==============================] - 11s 22ms/step - loss: 0.4900 - accuracy: 0.8431 - val_loss: 0.5615 - val_accuracy: 0.8269
# Epoch 8/50
# 500/500 [==============================] - 11s 21ms/step - loss: 0.4846 - accuracy: 0.8461 - val_loss: 0.5662 - val_accuracy: 0.8219
# Epoch 9/50
# 500/500 [==============================] - 11s 22ms/step - loss: 0.4781 - accuracy: 0.8492 - val_loss: 0.5192 - val_accuracy: 0.8433
# Epoch 10/50
# 500/500 [==============================] - 11s 21ms/step - loss: 0.4599 - accuracy: 0.8518 - val_loss: 0.5373 - val_accuracy: 0.8384
# Epoch 11/50
# 500/500 [==============================] - 11s 21ms/step - loss: 0.4603 - accuracy: 0.8534 - val_loss: 0.5114 - val_accuracy: 0.8479
# Epoch 12/50
# 500/500 [==============================] - 11s 21ms/step - loss: 0.4516 - accuracy: 0.8559 - val_loss: 0.5160 - val_accuracy: 0.8385
# Epoch 13/50
# 500/500 [==============================] - 10s 21ms/step - loss: 0.4531 - accuracy: 0.8555 - val_loss: 0.5332 - val_accuracy: 0.8394
# Epoch 14/50
# 500/500 [==============================] - 11s 23ms/step - loss: 0.4384 - accuracy: 0.8604 - val_loss: 0.5070 - val_accuracy: 0.8421
# Epoch 15/50
# 500/500 [==============================] - 11s 22ms/step - loss: 0.4193 - accuracy: 0.8621 - val_loss: 0.5228 - val_accuracy: 0.8435
# Epoch 16/50
# 500/500 [==============================] - 11s 22ms/step - loss: 0.4263 - accuracy: 0.8674 - val_loss: 0.5766 - val_accuracy: 0.8268
# Epoch 17/50
# 500/500 [==============================] - 11s 21ms/step - loss: 0.4185 - accuracy: 0.8677 - val_loss: 0.5414 - val_accuracy: 0.8303
# Epoch 18/50
# 500/500 [==============================] - 11s 22ms/step - loss: 0.4176 - accuracy: 0.8654 - val_loss: 0.4915 - val_accuracy: 0.8494
# Epoch 19/50
# 500/500 [==============================] - 10s 21ms/step - loss: 0.4040 - accuracy: 0.8682 - val_loss: 0.5175 - val_accuracy: 0.8455
# Epoch 20/50
# 500/500 [==============================] - 10s 21ms/step - loss: 0.3999 - accuracy: 0.8708 - val_loss: 0.5805 - val_accuracy: 0.8322
# Epoch 21/50
# 500/500 [==============================] - 10s 21ms/step - loss: 0.3823 - accuracy: 0.8779 - val_loss: 0.5002 - val_accuracy: 0.8529
# Epoch 22/50
# 500/500 [==============================] - 10s 21ms/step - loss: 0.3874 - accuracy: 0.8767 - val_loss: 0.5298 - val_accuracy: 0.8432
# Epoch 23/50
# 500/500 [==============================] - 10s 21ms/step - loss: 0.3936 - accuracy: 0.8780 - val_loss: 0.4874 - val_accuracy: 0.8488
# Epoch 24/50
# 500/500 [==============================] - 10s 21ms/step - loss: 0.3829 - accuracy: 0.8755 - val_loss: 0.4819 - val_accuracy: 0.8538
# Epoch 25/50
# 500/500 [==============================] - 10s 21ms/step - loss: 0.3615 - accuracy: 0.8819 - val_loss: 0.5073 - val_accuracy: 0.8522
# Epoch 26/50
# 500/500 [==============================] - 10s 21ms/step - loss: 0.3771 - accuracy: 0.8793 - val_loss: 0.5041 - val_accuracy: 0.8480
# Epoch 27/50
# 500/500 [==============================] - 11s 21ms/step - loss: 0.3665 - accuracy: 0.8830 - val_loss: 0.5057 - val_accuracy: 0.8498
# Epoch 28/50
# 500/500 [==============================] - 11s 21ms/step - loss: 0.3628 - accuracy: 0.8834 - val_loss: 0.5179 - val_accuracy: 0.8489
# Epoch 29/50
# 500/500 [==============================] - 11s 21ms/step - loss: 0.3581 - accuracy: 0.8854 - val_loss: 0.4640 - val_accuracy: 0.8639
# Epoch 30/50
# 500/500 [==============================] - 11s 21ms/step - loss: 0.3618 - accuracy: 0.8842 - val_loss: 0.5292 - val_accuracy: 0.8422
# Epoch 31/50
# 500/500 [==============================] - 10s 21ms/step - loss: 0.3527 - accuracy: 0.8881 - val_loss: 0.4949 - val_accuracy: 0.8477
# Epoch 32/50
# 500/500 [==============================] - 10s 21ms/step - loss: 0.3559 - accuracy: 0.8875 - val_loss: 0.4517 - val_accuracy: 0.8570
# Epoch 33/50
# 500/500 [==============================] - 10s 21ms/step - loss: 0.3507 - accuracy: 0.8907 - val_loss: 0.4618 - val_accuracy: 0.8611
# Epoch 34/50
# 500/500 [==============================] - 10s 21ms/step - loss: 0.3515 - accuracy: 0.8858 - val_loss: 0.5483 - val_accuracy: 0.8401
# Epoch 35/50
# 500/500 [==============================] - 11s 22ms/step - loss: 0.3305 - accuracy: 0.8962 - val_loss: 0.5200 - val_accuracy: 0.8412
# Epoch 36/50
# 500/500 [==============================] - 11s 22ms/step - loss: 0.3325 - accuracy: 0.8901 - val_loss: 0.4845 - val_accuracy: 0.8510
# Epoch 37/50
# 500/500 [==============================] - 11s 21ms/step - loss: 0.3347 - accuracy: 0.8924 - val_loss: 0.5021 - val_accuracy: 0.8600
# Epoch 38/50
# 500/500 [==============================] - 10s 21ms/step - loss: 0.3339 - accuracy: 0.8908 - val_loss: 0.4715 - val_accuracy: 0.8626
# Epoch 39/50
# 500/500 [==============================] - 11s 22ms/step - loss: 0.3292 - accuracy: 0.8935 - val_loss: 0.4907 - val_accuracy: 0.8577
# Epoch 40/50
# 500/500 [==============================] - 11s 21ms/step - loss: 0.3336 - accuracy: 0.8936 - val_loss: 0.4992 - val_accuracy: 0.8521
# Epoch 41/50
# 500/500 [==============================] - 11s 21ms/step - loss: 0.3266 - accuracy: 0.8971 - val_loss: 0.4781 - val_accuracy: 0.8604
# Epoch 42/50
# 500/500 [==============================] - 10s 21ms/step - loss: 0.3126 - accuracy: 0.8992 - val_loss: 0.4926 - val_accuracy: 0.8501
# Epoch 43/50
# 500/500 [==============================] - 11s 21ms/step - loss: 0.3258 - accuracy: 0.8994 - val_loss: 0.4872 - val_accuracy: 0.8591
# Epoch 44/50
# 500/500 [==============================] - 11s 22ms/step - loss: 0.3318 - accuracy: 0.8925 - val_loss: 0.5049 - val_accuracy: 0.8630
# Epoch 45/50
# 500/500 [==============================] - 11s 21ms/step - loss: 0.3096 - accuracy: 0.8991 - val_loss: 0.4730 - val_accuracy: 0.8574
# Epoch 46/50
# 500/500 [==============================] - 11s 21ms/step - loss: 0.3007 - accuracy: 0.9019 - val_loss: 0.4742 - val_accuracy: 0.8582
# Epoch 47/50
# 500/500 [==============================] - 10s 21ms/step - loss: 0.3128 - accuracy: 0.8968 - val_loss: 0.6109 - val_accuracy: 0.8360
# Epoch 48/50
# 500/500 [==============================] - 10s 21ms/step - loss: 0.3027 - accuracy: 0.8994 - val_loss: 0.4716 - val_accuracy: 0.8610
# Epoch 49/50
# 500/500 [==============================] - 10s 21ms/step - loss: 0.3061 - accuracy: 0.9013 - val_loss: 0.5140 - val_accuracy: 0.8550
# Epoch 50/50
# 500/500 [==============================] - 10s 21ms/step - loss: 0.2962 - accuracy: 0.9085 - val_loss: 0.5169 - val_accuracy: 0.8508

# %%
# Plot accuracy per iteration
plt.plot(r.history['accuracy'], label='acc')
plt.plot(r.history['val_accuracy'], label='val_acc')
plt.legend()

# %%
# predictions
from sklearn.metrics import confusion_matrix , classification_report

Y_pred = model.predict(X_test)
y_pred_classes = [np.argmax(element) for element in Y_pred]

print("Classification Report: \n", classification_report(Y_test, y_pred_classes))
# Out:
# 313/313 [==============================] - 1s 3ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.88      0.88      1000
#            1       0.96      0.93      0.94      1000
#            2       0.70      0.89      0.78      1000
#            3       0.78      0.66      0.71      1000
#            4       0.86      0.82      0.84      1000
#            5       0.87      0.70      0.78      1000
#            6       0.73      0.96      0.83      1000
#            7       0.95      0.84      0.90      1000
#            8       0.95      0.91      0.93      1000
#            9       0.91      0.93      0.92      1000
#
#     accuracy                           0.85     10000
#    macro avg       0.86      0.85      0.85     10000
# weighted avg       0.86      0.85      0.85     10000

# %%
# label mapping

labels = '''airplane automobile bird cat deerdog frog horseship truck'''.split()

# select the image from our test dataset
image_number = 3

# display the image
plt.imshow(X_test[image_number])

# load the image in an array
n = np.array(X_test[image_number])

# reshape it
p = n.reshape(1, 32, 32, 3)

# pass in the network for prediction and
# save the predicted label
predicted_label = labels[model.predict(p).argmax()]

# load the original label
original_label = labels[Y_test[image_number]]

# display the result
print("Original label is {} and predicted label is {}".format(
	original_label, predicted_label))
# Out:
# 1/1 [==============================] - 0s 131ms/step
# Original label is airplane and predicted label is airplane

# %%
# save the model
model.save('CNN_zahra.h5')
